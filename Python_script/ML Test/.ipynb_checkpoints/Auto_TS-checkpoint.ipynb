# %%
import pandas as pd
from auto_ts import auto_timeseries
from datetime import datetime, date
import matplotlib.pyplot as plt

path = 'C:\\Users\\Thunyavut\\Desktop\\Finance-Made-Easy-Personalized-Planner\\Python_script\\ssf_nav_data\\'
file = 'M0017_2565_SSF.csv'
df = pd.read_csv(f'{path}{file}')

train_size = int(len(df) * 0.7)
train = df[:train_size]
test = df[train_size:]

df['nav_date'] = pd.to_datetime(df['nav_date'])

# Define the time column and target column names
time_column = 'nav_date'
target_column = 'last_val'

# Initialize the AutoTS model
model = auto_timeseries(score_type='rmse')

# Fit the model on the time series data
model.fit(traindata=train, ts_column=time_column, target=target_column, cv=5)

# Predict future values
future_predictions = model.predict(test)
print(future_predictions)
# Out:
# Start of Fit.....
#     Target variable given as = last_val
# Start of loading of data.....
#     Inputs: ts_column = nav_date, sep = ,, target = ['last_val']
#     Using given input: pandas dataframe...
#     nav_date column exists in given train data...
#     train data shape = (135, 6)
#     detected strf_time_format as %Y-%m-%d in train data. You can change it in setup if this is incorrect.
#
# Running Augmented Dickey-Fuller test with paramters:
#     maxlag: 31 regression: c autolag: BIC
# Data is stationary after one differencing
# There is 1 differencing needed in this datasets for VAR model
#     No time series plot since verbose = 0. Continuing
# Time Interval between observations has not been provided. Auto_TS will try to infer this now...
# Time series input in days = 1
# It is a Daily time series.
#
#
# ==================================================
# Building Auto SARIMAX Model
# ==================================================
#
#
#
# Running Auto SARIMAX Model...
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=793.940, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-25.441, Time=0.06 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=-24.341, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=-25.090, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-37.005, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=48.942, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-37.545, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=141.615, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-36.902, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-35.075, Time=0.14 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.830 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=829.485, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-30.707, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=-29.309, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=-27.962, Time=0.10 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-41.768, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=50.400, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-42.055, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=147.145, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-41.703, Time=0.06 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-39.781, Time=0.06 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.721 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=865.187, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-34.729, Time=0.06 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-32.524, Time=0.10 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=-33.118, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=-31.069, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-46.952, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=48.977, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-46.856, Time=0.15 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-44.954, Time=0.07 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-44.955, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=151.025, Time=0.02 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=1.126, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-46.950, Time=0.05 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-42.952, Time=0.18 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 1.157 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=900.869, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-37.288, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-35.430, Time=0.07 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=-36.062, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=-33.968, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-49.789, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=48.101, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-49.976, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=154.054, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-49.763, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-47.782, Time=0.06 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.626 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=935.975, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-41.070, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-39.382, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=-39.393, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=-37.381, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-50.883, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=58.476, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-50.765, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-48.883, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-48.884, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=170.942, Time=0.02 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=8.887, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-50.884, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=-48.885, Time=0.13 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=-47.002, Time=0.18 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0] intercept
# Total fit time: 1.187 seconds
#
# SARIMAX RMSE (all folds): 0.4275
# SARIMAX Norm RMSE (all folds): 84%
#
#
# -------------------------------------------
# Model Cross Validation Results:
# -------------------------------------------
#     MAE (Mean Absolute Error = 0.38
#     MSE (Mean Squared Error = 0.20
#     MAPE (Mean Absolute Percent Error) = 5%
#     RMSE (Root Mean Squared Error) = 0.4469
#     Normalized RMSE (MinMax) = 29%
#     Normalized RMSE (as Std Dev of Actuals)= 99%
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-53.342, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-52.079, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-52.170, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-54.901, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-50.503, Time=0.06 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.142 seconds
# Refitting data with previously found best parameters
#     Best aic metric = -159.2
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               last_val   No. Observations:                  135
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                  87.592
# Date:                Mon, 05 Jun 2023   AIC                           -159.183
# Time:                        05:52:59   BIC                           -136.060
# Sample:                             0   HQIC                          -149.787
#                                 - 135
# Covariance Type:                  opg
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept          -0.0316      0.027     -1.153      0.249      -0.085       0.022
# drift           -1.194e-05      0.000     -0.032      0.975      -0.001       0.001
# net_asset        7.543e-08   5.04e-09     14.971      0.000    6.56e-08    8.53e-08
# sell_price         36.3945      0.003   1.27e+04      0.000      36.389      36.400
# buy_price         -36.9743      0.003  -1.31e+04      0.000     -36.980     -36.969
# sell_swap_price   -36.9743      0.003  -1.31e+04      0.000     -36.980     -36.969
# buy_swap_price     36.3945      0.003   1.27e+04      0.000      36.389      36.400
# sigma2              0.0178      0.002      9.478      0.000       0.014       0.021
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.64   Jarque-Bera (JB):               962.50
# Prob(Q):                              0.42   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.21   Skew:                            -1.62
# Prob(H) (two-sided):                  0.53   Kurtosis:                        15.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.73e+18. Standard errors may be unstable.
#
# Best Model is: auto_SARIMAX
#     Best Model (Mean CV) Score: 0.43
#
#
# --------------------------------------------------
# Total time taken: 5 seconds.
# --------------------------------------------------
#
#
# Leaderboard with best model on top of list:
#             name      rmse
# 0  auto_SARIMAX  0.427495
# Predicting using test dataframe as input for auto_SARIMAX model
# last_val      yhat   mean_se  mean_ci_lower  mean_ci_upper
# 135       7.745026  0.133270       7.483822       8.006231
# 136       7.595305  0.188472       7.225906       7.964704
# 137       7.502803  0.230831       7.050383       7.955222
# 138       7.259193  0.266540       6.736784       7.781602
# 139       6.972585  0.298001       6.388514       7.556657
# 140       6.976713  0.326444       6.336895       7.616531
# 141       6.941231  0.352599       6.250149       7.632313
# 142       6.954535  0.376945       6.215737       7.693333
# 143       6.959669  0.399810       6.176055       7.743283
# 144       7.282683  0.421437       6.456682       8.108684
# 145       7.164936  0.442007       6.298618       8.031253
# 146       7.327507  0.461661       6.422668       8.232346
# 147       7.509596  0.480512       6.567810       8.451383
# 148       7.099199  0.498651       6.121861       8.076537
# 149       6.857505  0.516153       5.845864       7.869146
# 150       6.724431  0.533080       5.679613       7.769249
# 151       6.752132  0.549487       5.675158       7.829106
# 152       7.177672  0.565417       6.069475       8.285869
# 153       7.021036  0.580911       5.882471       8.159600
# 154       7.085550  0.596002       5.917408       8.253692
# 155       7.376819  0.610720       6.179830       8.573809
# 156       7.299855  0.625092       6.074697       8.525013
# 157       7.004822  0.639141       5.752129       8.257515
# 158       6.694745  0.652887       5.415110       7.974381
# 159       7.089258  0.666350       5.783236       8.395281
# 160       7.183577  0.679547       5.851690       8.515464
# 161       7.092193  0.692492       5.734935       8.449452
# 162       7.419368  0.705199       6.037204       8.801533
# 163       7.206542  0.717681       5.799913       8.613172
# 164       7.402538  0.729950       5.971862       8.833214
# 165       7.683824  0.742016       6.229499       9.138149
# 166       7.555973  0.753889       6.078377       9.033569
# 167       7.521187  0.765578       6.020681       9.021693
# 168       7.584573  0.777091       6.061502       9.107644
# 169       7.501048  0.788436       5.955741       9.046355
# 170       7.388056  0.799620       5.820829       8.955283
# 171       7.231235  0.810650       5.642389       8.820080
# 172       7.351314  0.821532       5.741141       8.961487
# 173       7.738807  0.832271       6.107585       9.370029
# 174       7.974383  0.842874       6.322380       9.626386
# 175       7.345456  0.853345       5.672931       9.017981
# 176       6.994433  0.863689       5.301634       8.687232
# 177       6.998880  0.873910       5.286047       8.711713
# 178       6.969344  0.884014       5.236709       8.701979
# 179       6.815124  0.894003       5.062911       8.567338
# 180       6.958171  0.903882       5.186596       8.729746
# 181       6.836255  0.913654       5.045527       8.626983
# 182       6.652302  0.923322       4.842623       8.461980
# 183       6.617020  0.932891       4.788588       8.445452
# 184       6.441824  0.942362       4.594829       8.288820
# 185       6.377981  0.951739       4.512607       8.243354
# 186       6.345427  0.961024       4.461854       8.229000
# 187       6.148798  0.970221       4.247200       8.050396
# 188       5.904116  0.979331       3.984662       7.823569
# 189       5.831573  0.988357       3.894428       7.768718
# 190       5.837000  0.997302       3.882324       7.791676
# 191       5.664376  1.006167       3.692325       7.636427
# 192       5.823283  1.014955       3.834008       7.812557
# 193       5.774555  1.023667       3.768205       7.780906

# %%
plt.figure(figsize=(20, 6))
plt.scatter(test['nav_date'], test['last_val'], color='g', label='True values')
plt.plot(test['nav_date'], future_predictions['yhat'], color='r', label='Test predictions')
plt.xlabel('Date')
plt.ylabel('y')
plt.legend()
plt.xticks(rotation=45)
plt.show()
