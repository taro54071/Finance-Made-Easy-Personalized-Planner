# %%
import requests
import json

import pandas as pd

headers1 = {
    # Request headers of fund daily info
    'Ocp-Apim-Subscription-Key': 'c1714d1753d5947f5b8f6f3cb67354d1d'
}

headers2 = {
    # Request headers of fund fact sheet
    'Ocp-Apim-Subscription-Key': '89cbe200e6ee4afca33f6e2122aa5e82'
}

# %%
response = requests.get(f'https://api.sec.or.th/FundFactsheet/fund/amc/C0000000239', headers = headers2)
status = json.loads(response.text)
status_df = pd.DataFrame(status)
status_df_use = status_df[['proj_id','cancel_date','fund_status','proj_abbr_name','proj_name_en']]
status_df_use
# Out:
#          proj_id cancel_date fund_status proj_abbr_name
# 0     M0001_2538  2004-04-09          CA          SCBFI  \
# 1     M0001_2545           -          EX       SCBSOF 4
# 2     M0001_2549  2015-01-28          LI      SCBGB1/12
# 3     M0001_2559  2016-04-22          LI      SCBAI3M12
# 4     M0002_2540  2003-03-31          LI          SCBGB
# ...          ...         ...         ...            ...
# 2796  M1233_2557  2015-02-06          LI      SCBTG3P3A
# 2797  M1235_2557  2015-05-01          LI     SCBASF3M59
# 2798  M1236_2557  2015-07-24          LI     SCBASF6M52
# 2799  M1237_2557  2016-02-19          LI     SCBASF1Y18
# 2800  M1246_2557  2015-07-30          LI     SCBASF6M53
#
#                                            proj_name_en
# 0                        SCB FIXED INCOME OPEN END FUND
# 1                          SCB SPECIFIC 4 OPEN END FUND
# 2                SCB GOVERNMENT BOND 1/12 OPEN END FUND
# 3       SCB FIXED INCOME ACCREDITED INVESTORS FUND 3M12
# 4                     SCB GOVERNMENT BOND OPEN END FUND
# ...                                                 ...
# 2796                      SCB TRIGGER 3% PLUS 3% FUND A
# 2797  SCB FOREIGN FIXED INCOME ACCREDITED INVESTORS ...
# 2798  SCB FOREIGN FIXED INCOME ACCREDITED INVESTORS ...
# 2799  SCB FOREIGN FIXED INCOME ACCREDITED INVESTORS ...
# 2800  SCB FOREIGN FIXED INCOME ACCREDITED INVESTORS ...
#
# [2801 rows x 5 columns]

# %%
import pandas as pd
SCB_amc_data = pd.DataFrame(columns = ['proj_id','risk_spectrum','spec_code','amc','name_th','proj_retail_type'])
file = pd.read_csv('./amc_data/SCB_amc_data/SCB_AMC_DATA.csv')
file['amc'] =  'C0000000239'
file['name_th'] = 'บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด'
SCB_amc_data = pd.concat([SCB_amc_data,file])
SCB_amc_data_clean = SCB_amc_data.dropna(subset=['spec_code','proj_retail_type'])
SCB_amc_data_clean.drop(SCB_amc_data_clean[SCB_amc_data_clean['proj_retail_type'] != 'R'].index, inplace = True)
SCB_amc_no_rmf_ssf = SCB_amc_data_clean[~(SCB_amc_data_clean['spec_code'].str.contains('RMF', case=False, na=False) | SCB_amc_data_clean['spec_code'].str.contains('SSF', case=False, na=False))]
len(SCB_amc_no_rmf_ssf)
# Out:
# C:\Users\THIS-PC\AppData\Local\Temp\ipykernel_20560\2797317666.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SCB_amc_data_clean.drop(SCB_amc_data_clean[SCB_amc_data_clean['proj_retail_type'] != 'R'].index, inplace = True)
# 1173

# %%
SCB_amc_no_rmf_ssf = SCB_amc_no_rmf_ssf.reset_index()
SCB_amc_no_rmf_ssf.drop(columns=['index'])
SCB_amc_no_rmf_ssf
# Out:
#       index     proj_id risk_spectrum spec_code          amc
# 0        12  M0003_2554           NaN       SPF  C0000000239  \
# 1        20  M0004_2564           NaN       FED  C0000000239
# 2        25  M0005_2556           NaN   FIF,SPF  C0000000239
# 3        35  M0006_2556           NaN   FIF,SPF  C0000000239
# 4        36  M0006_2558           NaN       SPF  C0000000239
# ...     ...         ...           ...       ...          ...
# 1168   2762  M1086_2557           NaN   FIF,SPF  C0000000239
# 1169   2774  M1126_2557           NaN       SPF  C0000000239
# 1170   2775  M1127_2557           NaN       SPF  C0000000239
# 1171   2782  M1179_2557           NaN       SPF  C0000000239
# 1172   2796  M1233_2557           NaN       SPF  C0000000239
#
#                                             name_th proj_retail_type
# 0     บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 1     บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 2     บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 3     บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 4     บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# ...                                             ...              ...
# 1168  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 1169  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 1170  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 1171  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 1172  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
#
# [1173 rows x 7 columns]

# %%
SCB_amc_no_rmf_ssf = pd.merge(SCB_amc_no_rmf_ssf, status_df_use, on='proj_id')
SCB_amc_no_rmf_ssf
# Out:
#       index     proj_id risk_spectrum spec_code          amc
# 0        12  M0003_2554           NaN       SPF  C0000000239  \
# 1        20  M0004_2564           NaN       FED  C0000000239
# 2        25  M0005_2556           NaN   FIF,SPF  C0000000239
# 3        35  M0006_2556           NaN   FIF,SPF  C0000000239
# 4        36  M0006_2558           NaN       SPF  C0000000239
# ...     ...         ...           ...       ...          ...
# 1168   2762  M1086_2557           NaN   FIF,SPF  C0000000239
# 1169   2774  M1126_2557           NaN       SPF  C0000000239
# 1170   2775  M1127_2557           NaN       SPF  C0000000239
# 1171   2782  M1179_2557           NaN       SPF  C0000000239
# 1172   2796  M1233_2557           NaN       SPF  C0000000239
#
#                                             name_th proj_retail_type
# 0     บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R  \
# 1     บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 2     บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 3     บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 4     บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# ...                                             ...              ...
# 1168  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 1169  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 1170  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 1171  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 1172  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
#
#      cancel_date fund_status proj_abbr_name
# 0     2014-01-21          LI       SCBFI3Y3  \
# 1              -          RG          SCBAA
# 2     2013-04-19          LI      SCBFF3M20
# 3     2013-04-30          LI      SCBFF3M21
# 4              -          EX      SCBFI3M78
# ...          ...         ...            ...
# 1168  2015-09-04          LI      SCBFF6M94
# 1169  2014-11-24          EX      SCBFI6M96
# 1170           -          EX      SCBFI6M97
# 1171           -          EX      SCBFI6M98
# 1172  2015-02-06          LI      SCBTG3P3A
#
#                             proj_name_en
# 0              SCB FIXED INCOME FUND 3Y3
# 1             SCB Active Allocation Fund
# 2     SCB FOREIGN FIXED INCOME FUND 3M20
# 3     SCB FOREIGN FIXED INCOME FUND 3M21
# 4             SCB FIXED INCOME FUND 3M78
# ...                                  ...
# 1168  SCB FOREIGN FIXED INCOME FUND 6M94
# 1169          SCB FIXED INCOME FUND 6M96
# 1170          SCB FIXED INCOME FUND 6M97
# 1171          SCB FIXED INCOME FUND 6M98
# 1172       SCB TRIGGER 3% PLUS 3% FUND A
#
# [1173 rows x 11 columns]

# %%
SCB_amc_no_rmf_ssf = SCB_amc_no_rmf_ssf.drop(SCB_amc_no_rmf_ssf[SCB_amc_no_rmf_ssf["cancel_date"]!="-"].index)
SCB_amc_no_rmf_ssf = SCB_amc_no_rmf_ssf.drop(SCB_amc_no_rmf_ssf[SCB_amc_no_rmf_ssf["fund_status"]=="EX"].index)
SCB_amc_no_rmf_ssf
# Out:
#       index     proj_id risk_spectrum spec_code          amc
# 1        20  M0004_2564           NaN       FED  C0000000239  \
# 19       81  M0015_2564           NaN       FED  C0000000239
# 29      121  M0024_2560           NaN       FED  C0000000239
# 31      128  M0026_2539           NaN       IND  C0000000239
# 32      129  M0026_2551           NaN       FED  C0000000239
# ...     ...         ...           ...       ...          ...
# 1118   2692  M0936_2566           NaN       CRF  C0000000239
# 1119   2694  M0937_2566           NaN       CRF  C0000000239
# 1121   2696  M0938_2566           NaN       CRF  C0000000239
# 1123   2698  M0939_2566           NaN       CRF  C0000000239
# 1126   2701  M0940_2566           NaN       CRF  C0000000239
#
#                                             name_th proj_retail_type
# 1     บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R  \
# 19    บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 29    บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 31    บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 32    บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# ...                                             ...              ...
# 1118  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 1119  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 1121  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 1123  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 1126  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
#
#      cancel_date fund_status proj_abbr_name
# 1              -          RG          SCBAA  \
# 19             -          RG          SCBAO
# 29             -          RG        SCBUSHY
# 31             -          RG     SCBSETFUND
# 32             -          RG     SCBAEMFUND
# ...          ...         ...            ...
# 1118           -          RG      SCBCP3M49
# 1119           -          RG      SCBCP3M50
# 1121           -          RG      SCBCP6M34
# 1123           -          RG      SCBCP6M33
# 1126           -          RG      SCBCP6M35
#
#                                       proj_name_en
# 1                       SCB Active Allocation Fund
# 19                       SCB Asia Opportunity Fund
# 29          SCB US Short Duration High Income Bond
# 31                           SCB SET INDEX FUND
# 32    SCB ASIAN EMERGING MARKETS OPEN END FUND
# ...                                            ...
# 1118                   SCB Capital Protection 3M49
# 1119                   SCB Capital Protection 3M50
# 1121                   SCB Capital Protection 6M34
# 1123                   SCB Capital Protection 6M33
# 1126                   SCB Capital Protection 6M35
#
# [95 rows x 11 columns]

# %%
SCB_amc_no_rmf_ssf = SCB_amc_no_rmf_ssf.reset_index()

# %%
SCB_amc_no_rmf_ssf = SCB_amc_no_rmf_ssf.drop(columns=['level_0','index'])
SCB_amc_no_rmf_ssf
# Out:
#        proj_id risk_spectrum spec_code          amc
# 0   M0004_2564           NaN       FED  C0000000239  \
# 1   M0015_2564           NaN       FED  C0000000239
# 2   M0024_2560           NaN       FED  C0000000239
# 3   M0026_2539           NaN       IND  C0000000239
# 4   M0026_2551           NaN       FED  C0000000239
# ..         ...           ...       ...          ...
# 90  M0936_2566           NaN       CRF  C0000000239
# 91  M0937_2566           NaN       CRF  C0000000239
# 92  M0938_2566           NaN       CRF  C0000000239
# 93  M0939_2566           NaN       CRF  C0000000239
# 94  M0940_2566           NaN       CRF  C0000000239
#
#                                           name_th proj_retail_type
# 0   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R  \
# 1   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 2   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 3   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 4   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# ..                                            ...              ...
# 90  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 91  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 92  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 93  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 94  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
#
#    cancel_date fund_status proj_abbr_name
# 0            -          RG          SCBAA  \
# 1            -          RG          SCBAO
# 2            -          RG        SCBUSHY
# 3            -          RG     SCBSETFUND
# 4            -          RG     SCBAEMFUND
# ..         ...         ...            ...
# 90           -          RG      SCBCP3M49
# 91           -          RG      SCBCP3M50
# 92           -          RG      SCBCP6M34
# 93           -          RG      SCBCP6M33
# 94           -          RG      SCBCP6M35
#
#                                     proj_name_en
# 0                     SCB Active Allocation Fund
# 1                      SCB Asia Opportunity Fund
# 2         SCB US Short Duration High Income Bond
# 3                          SCB SET INDEX FUND
# 4   SCB ASIAN EMERGING MARKETS OPEN END FUND
# ..                                           ...
# 90                   SCB Capital Protection 3M49
# 91                   SCB Capital Protection 3M50
# 92                   SCB Capital Protection 6M34
# 93                   SCB Capital Protection 6M33
# 94                   SCB Capital Protection 6M35
#
# [95 rows x 10 columns]

# %%
import re
import pdfbox
import os
from IPython.display import clear_output
p = pdfbox.PDFBox()
not_screenable = []
max_len = len(SCB_amc_no_rmf_ssf)
for index, row in SCB_amc_no_rmf_ssf.iterrows():
        response = requests.get(f'https://api.sec.or.th/FundFactsheet/fund/{row["proj_id"]}/URLs',headers=headers2)
        res_text = json.loads(response.text)
        res_pdf = requests.get(res_text['url_factsheet'])
        with open(f"tmp/tmp.pdf", 'wb') as pdf_file:
                pdf_file.write(res_pdf.content)
        try:
                print(str(index+1) + ' of ' + str(max_len) +' '+ str(round(((index+1)/max_len)*100,2))+' % Completed' )
                if os.path.getsize("tmp/tmp.pdf") < 216:
                        raise Exception("File not found ::") 
                p.extract_text(f'tmp/tmp.pdf')
                with open(f'tmp/tmp.txt', 'r',  encoding="utf8") as file:
                        data = file.read()
                match1 = re.search(r'(\S+)\s*:\s*เสี่ยง', data)
                match2 = re.search(r'(\S+)\s*:\s*เสียง', data)
                match3 = re.search(r'(\S+)\s*:\s*เสยง', data)
                if match1:
                        number_before_string = match1.group(1)
                        SCB_amc_no_rmf_ssf.at[index, 'risk_spectrum'] = number_before_string
                elif match2:
                        number_before_string = match2.group(1)
                        SCB_amc_no_rmf_ssf.at[index, 'risk_spectrum'] = number_before_string
                elif match3:
                        number_before_string = match3.group(1)
                        SCB_amc_no_rmf_ssf.at[index, 'risk_spectrum'] = number_before_string
                else:
                        print("Pattern not found on "+ row["proj_id"])
                        not_screenable.append(row["proj_id"])
                clear_output(wait=True)
        except Exception as e:
                print(str(e) +' Error found on '+ row['proj_id'])
# Out:
# 95 of 95 100.0 % Completed

# %%
not_screenable
# Out:
# ['M0241_2554',
#  'M0263_2566',
#  'M0329_2566',
#  'M0511_2566',
#  'M0522_2555',
#  'M0549_2566',
#  'M0570_2566',
#  'M0882_2554']

# %%
for proj_id in not_screenable:
        response = requests.get(f'https://api.sec.or.th/FundFactsheet/fund/{proj_id}/URLs',headers=headers2)
        res_text = json.loads(response.text)
        res_pdf = requests.get(res_text['url_factsheet'])
        with open(f"tmp/{proj_id}.pdf", 'wb') as pdf_file:
                pdf_file.write(res_pdf.content)

# %%
SCB_amc_no_rmf_ssf
# Out:
#        proj_id risk_spectrum spec_code          amc
# 0   M0004_2564             5       FED  C0000000239  \
# 1   M0015_2564             6       FED  C0000000239
# 2   M0024_2560             6       FED  C0000000239
# 3   M0026_2539             6       IND  C0000000239
# 4   M0026_2551             6       FED  C0000000239
# ..         ...           ...       ...          ...
# 90  M0936_2566             3       CRF  C0000000239
# 91  M0937_2566             3       CRF  C0000000239
# 92  M0938_2566             3       CRF  C0000000239
# 93  M0939_2566             3       CRF  C0000000239
# 94  M0940_2566             3       CRF  C0000000239
#
#                                           name_th proj_retail_type
# 0   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R  \
# 1   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 2   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 3   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 4   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# ..                                            ...              ...
# 90  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 91  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 92  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 93  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 94  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
#
#    cancel_date fund_status proj_abbr_name
# 0            -          RG          SCBAA  \
# 1            -          RG          SCBAO
# 2            -          RG        SCBUSHY
# 3            -          RG     SCBSETFUND
# 4            -          RG     SCBAEMFUND
# ..         ...         ...            ...
# 90           -          RG      SCBCP3M49
# 91           -          RG      SCBCP3M50
# 92           -          RG      SCBCP6M34
# 93           -          RG      SCBCP6M33
# 94           -          RG      SCBCP6M35
#
#                                     proj_name_en
# 0                     SCB Active Allocation Fund
# 1                      SCB Asia Opportunity Fund
# 2         SCB US Short Duration High Income Bond
# 3                          SCB SET INDEX FUND
# 4   SCB ASIAN EMERGING MARKETS OPEN END FUND
# ..                                           ...
# 90                   SCB Capital Protection 3M49
# 91                   SCB Capital Protection 3M50
# 92                   SCB Capital Protection 6M34
# 93                   SCB Capital Protection 6M33
# 94                   SCB Capital Protection 6M35
#
# [95 rows x 10 columns]

# %%
SCB_amc_no_rmf_ssf_nan = SCB_amc_no_rmf_ssf[SCB_amc_no_rmf_ssf.isna().any(axis=1)]
SCB_amc_no_rmf_ssf_nan
# Out:
#        proj_id risk_spectrum spec_code          amc
# 22  M0241_2554           NaN       FED  C0000000239  \
# 25  M0263_2566           NaN       CRF  C0000000239
# 30  M0329_2566           NaN       CRF  C0000000239
# 40  M0511_2566           NaN       CRF  C0000000239
# 42  M0522_2555           NaN       FED  C0000000239
# 44  M0549_2566           NaN       CRF  C0000000239
# 46  M0570_2566           NaN       CRF  C0000000239
# 82  M0882_2554           NaN       FED  C0000000239
#
#                                           name_th proj_retail_type
# 22  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R  \
# 25  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 30  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 40  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 42  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 44  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 46  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 82  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
#
#    cancel_date fund_status proj_abbr_name                 proj_name_en
# 22           -          RG    SCBGOLDFUND       SCB GOLD OPEN END FUND
# 25           -          RG       SCBCP1Y7   SCB Capital Protection 1Y7
# 30           -          RG       SCBCP1Y8   SCB Capital Protection 1Y8
# 40           -          RG      SCBCP6M15  SCB Capital Protection 6M15
# 42           -          RG     SCBOILFUND                 SCB OIL FUND
# 44           -          RG      SCBCP6M16  SCB Capital Protection 6M16
# 46           -          RG      SCBCP6M17  SCB Capital Protection 6M17
# 82           -          RG        SCBCOMP      SCB COMMODITY PLUS FUND

# %%
SCB_amc_no_rmf_ssf = SCB_amc_no_rmf_ssf.dropna()
SCB_amc_no_rmf_ssf
# Out:
#        proj_id risk_spectrum spec_code          amc
# 0   M0004_2564             5       FED  C0000000239  \
# 1   M0015_2564             6       FED  C0000000239
# 2   M0024_2560             6       FED  C0000000239
# 3   M0026_2539             6       IND  C0000000239
# 4   M0026_2551             6       FED  C0000000239
# ..         ...           ...       ...          ...
# 90  M0936_2566             3       CRF  C0000000239
# 91  M0937_2566             3       CRF  C0000000239
# 92  M0938_2566             3       CRF  C0000000239
# 93  M0939_2566             3       CRF  C0000000239
# 94  M0940_2566             3       CRF  C0000000239
#
#                                           name_th proj_retail_type
# 0   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R  \
# 1   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 2   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 3   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 4   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# ..                                            ...              ...
# 90  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 91  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 92  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 93  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 94  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
#
#    cancel_date fund_status proj_abbr_name
# 0            -          RG          SCBAA  \
# 1            -          RG          SCBAO
# 2            -          RG        SCBUSHY
# 3            -          RG     SCBSETFUND
# 4            -          RG     SCBAEMFUND
# ..         ...         ...            ...
# 90           -          RG      SCBCP3M49
# 91           -          RG      SCBCP3M50
# 92           -          RG      SCBCP6M34
# 93           -          RG      SCBCP6M33
# 94           -          RG      SCBCP6M35
#
#                                     proj_name_en
# 0                     SCB Active Allocation Fund
# 1                      SCB Asia Opportunity Fund
# 2         SCB US Short Duration High Income Bond
# 3                          SCB SET INDEX FUND
# 4   SCB ASIAN EMERGING MARKETS OPEN END FUND
# ..                                           ...
# 90                   SCB Capital Protection 3M49
# 91                   SCB Capital Protection 3M50
# 92                   SCB Capital Protection 6M34
# 93                   SCB Capital Protection 6M33
# 94                   SCB Capital Protection 6M35
#
# [87 rows x 10 columns]

# %%
SCB_amc_no_rmf_ssf_nan
# Out:
#        proj_id risk_spectrum spec_code          amc
# 22  M0241_2554           NaN       FED  C0000000239  \
# 25  M0263_2566           NaN       CRF  C0000000239
# 30  M0329_2566           NaN       CRF  C0000000239
# 40  M0511_2566           NaN       CRF  C0000000239
# 42  M0522_2555           NaN       FED  C0000000239
# 44  M0549_2566           NaN       CRF  C0000000239
# 46  M0570_2566           NaN       CRF  C0000000239
# 82  M0882_2554           NaN       FED  C0000000239
#
#                                           name_th proj_retail_type
# 22  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R  \
# 25  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 30  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 40  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 42  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 44  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 46  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 82  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
#
#    cancel_date fund_status proj_abbr_name                 proj_name_en
# 22           -          RG    SCBGOLDFUND       SCB GOLD OPEN END FUND
# 25           -          RG       SCBCP1Y7   SCB Capital Protection 1Y7
# 30           -          RG       SCBCP1Y8   SCB Capital Protection 1Y8
# 40           -          RG      SCBCP6M15  SCB Capital Protection 6M15
# 42           -          RG     SCBOILFUND                 SCB OIL FUND
# 44           -          RG      SCBCP6M16  SCB Capital Protection 6M16
# 46           -          RG      SCBCP6M17  SCB Capital Protection 6M17
# 82           -          RG        SCBCOMP      SCB COMMODITY PLUS FUND

# %%
#read manually
risk_list = ['8','3','3','3','8','3','3','8']
SCB_amc_no_rmf_ssf_nan.loc[SCB_amc_no_rmf_ssf_nan['risk_spectrum'].isna(), 'risk_spectrum'] = risk_list
SCB_amc_no_rmf_ssf_nan
# Out:
# C:\Users\THIS-PC\AppData\Local\Temp\ipykernel_20560\2309943869.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SCB_amc_no_rmf_ssf_nan.loc[SCB_amc_no_rmf_ssf_nan['risk_spectrum'].isna(), 'risk_spectrum'] = risk_list
#        proj_id risk_spectrum spec_code          amc
# 22  M0241_2554             8       FED  C0000000239  \
# 25  M0263_2566             3       CRF  C0000000239
# 30  M0329_2566             3       CRF  C0000000239
# 40  M0511_2566             3       CRF  C0000000239
# 42  M0522_2555             8       FED  C0000000239
# 44  M0549_2566             3       CRF  C0000000239
# 46  M0570_2566             3       CRF  C0000000239
# 82  M0882_2554             8       FED  C0000000239
#
#                                           name_th proj_retail_type
# 22  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R  \
# 25  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 30  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 40  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 42  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 44  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 46  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 82  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
#
#    cancel_date fund_status proj_abbr_name                 proj_name_en
# 22           -          RG    SCBGOLDFUND       SCB GOLD OPEN END FUND
# 25           -          RG       SCBCP1Y7   SCB Capital Protection 1Y7
# 30           -          RG       SCBCP1Y8   SCB Capital Protection 1Y8
# 40           -          RG      SCBCP6M15  SCB Capital Protection 6M15
# 42           -          RG     SCBOILFUND                 SCB OIL FUND
# 44           -          RG      SCBCP6M16  SCB Capital Protection 6M16
# 46           -          RG      SCBCP6M17  SCB Capital Protection 6M17
# 82           -          RG        SCBCOMP      SCB COMMODITY PLUS FUND

# %%
result_SCB_amc_no_rmf_ssf = pd.concat([SCB_amc_no_rmf_ssf, SCB_amc_no_rmf_ssf_nan], ignore_index=True)

# %%
result_SCB_amc_no_rmf_ssf
# Out:
#        proj_id risk_spectrum spec_code          amc
# 0   M0004_2564             5       FED  C0000000239  \
# 1   M0015_2564             6       FED  C0000000239
# 2   M0024_2560             6       FED  C0000000239
# 3   M0026_2539             6       IND  C0000000239
# 4   M0026_2551             6       FED  C0000000239
# ..         ...           ...       ...          ...
# 90  M0511_2566             3       CRF  C0000000239
# 91  M0522_2555             8       FED  C0000000239
# 92  M0549_2566             3       CRF  C0000000239
# 93  M0570_2566             3       CRF  C0000000239
# 94  M0882_2554             8       FED  C0000000239
#
#                                           name_th proj_retail_type
# 0   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R  \
# 1   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 2   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 3   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 4   บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# ..                                            ...              ...
# 90  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 91  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 92  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 93  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
# 94  บริษัท หลักทรัพย์จัดการกองทุนไทยพาณิชย์ จำกัด                R
#
#    cancel_date fund_status proj_abbr_name
# 0            -          RG          SCBAA  \
# 1            -          RG          SCBAO
# 2            -          RG        SCBUSHY
# 3            -          RG     SCBSETFUND
# 4            -          RG     SCBAEMFUND
# ..         ...         ...            ...
# 90           -          RG      SCBCP6M15
# 91           -          RG     SCBOILFUND
# 92           -          RG      SCBCP6M16
# 93           -          RG      SCBCP6M17
# 94           -          RG        SCBCOMP
#
#                                     proj_name_en
# 0                     SCB Active Allocation Fund
# 1                      SCB Asia Opportunity Fund
# 2         SCB US Short Duration High Income Bond
# 3                          SCB SET INDEX FUND
# 4   SCB ASIAN EMERGING MARKETS OPEN END FUND
# ..                                           ...
# 90                   SCB Capital Protection 6M15
# 91                                  SCB OIL FUND
# 92                   SCB Capital Protection 6M16
# 93                   SCB Capital Protection 6M17
# 94                       SCB COMMODITY PLUS FUND
#
# [95 rows x 10 columns]

# %%
result_SCB_amc_no_rmf_ssf['proj_id'].nunique()
# Out:
# 95

# %%
result_SCB_amc_no_rmf_ssf.to_csv('../Result_amc/SCB/SCB_NON_RMF_SSF.csv', encoding='utf8')
